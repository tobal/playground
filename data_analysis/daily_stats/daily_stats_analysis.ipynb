# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

stats_df = pd.read_csv("stats.csv")

# %%
stats_df.corr(method='pearson')
# Out:
#           PSY       ACT       PHI       LRN       EAT       WTR       SLP  \
# PSY  1.000000  0.589724  0.304772  0.376744  0.200393  0.175358 -0.147130
# ACT  0.589724  1.000000  0.404286  0.516201  0.138948  0.246478 -0.107768
# PHI  0.304772  0.404286  1.000000  0.221379  0.002290  0.141498  0.019194
# LRN  0.376744  0.516201  0.221379  1.000000  0.090364  0.081108 -0.130334
# EAT  0.200393  0.138948  0.002290  0.090364  1.000000  0.019971 -0.136933
# WTR  0.175358  0.246478  0.141498  0.081108  0.019971  1.000000  0.014262
# SLP -0.147130 -0.107768  0.019194 -0.130334 -0.136933  0.014262  1.000000
# WTH  0.125926  0.013333  0.064767 -0.072869 -0.119766  0.130560  0.062405
#
#           WTH
# PSY  0.125926
# ACT  0.013333
# PHI  0.064767
# LRN -0.072869
# EAT -0.119766
# WTR  0.130560
# SLP  0.062405
# WTH  1.000000

# %%
stats_df.mean()
# Out:
# PSY    6.287356
# ACT    6.339080
# PHI    3.982759
# LRN    5.247126
# EAT    4.589474
# WTR    4.435294
# SLP    7.213793
# WTH    4.776860
# dtype: float64

# %%
def compute_and_plot_means(dataframe, column, aggr=10):
    means = pd.DataFrame()
    iters = len(dataframe) // aggr + 1
    for i in range(iters):
        df = pd.DataFrame(dataframe[column])[i * aggr:(i+1) * aggr]
        means[i] = df.mean()

    f = plt.figure(figsize=(20, 5))
    means.T.plot(ax=f.gca())
    plt.title('{} aggregated mean by {}'.format(column, aggr), color='black')

# %%
columns = list(stats_df.columns)[1:]
for column in columns:
    for i in [2, 5, 10, 20, 30]:
        compute_and_plot_means(stats_df, column, i)
# Out:
# /usr/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
